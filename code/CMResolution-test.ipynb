# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
font = {'size':16, 'family':'serif'}
matplotlib.rc('font', **font)

# %%
LMC_orbit = np.loadtxt('LMCtest.txt', skiprows=1)
MW_orbit = np.loadtxt('MWtest.txt', skiprows=1)
D_orbit = np.loadtxt('Disktest.txt', skiprows=1)

# %%
plot(MW_orbit[:,0], MW_orbit[:,1])
xscale('log')
plot(D_orbit[:,0], D_orbit[:,1])
xscale('log')

# %%
figure(figsize=(14, 6))
subplot(1, 2, 1)
plot(time_LR, Rgal_LR, lw=2, alpha=0.7)
plot(time_HR, Rgal_HR, lw=2, alpha=0.7)
xlabel('Time(Gyrs)', fontsize=25)
ylabel('Rgal(kpc)', fontsize=25)

subplot(1, 2, 2)
plot(time_LR, Vgal_LR, lw=2, alpha=0.7)
plot(time_HR, Vgal_HR, lw=2, alpha=0.7)
xlabel('Time(Gyrs)', fontsize=25)
ylabel('Vgal(km/s)', fontsize=25)
