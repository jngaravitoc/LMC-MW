# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
font = {'size':16, 'family':'serif'}
matplotlib.rc('font', **font)

# %%
LMC_orbit1 = np.loadtxt('LMCLMC45.txt', skiprows=1)
MW_orbit1 = np.loadtxt('MWLMC45.txt', skiprows=1)
D_orbit1 = np.loadtxt('DiskLMC45.txt', skiprows=1)

LMC_orbit2 = np.loadtxt('LMCLMC453.txt', skiprows=1)
MW_orbit2 = np.loadtxt('MWLMC453.txt', skiprows=1)
D_orbit2 = np.loadtxt('DiskLMC453.txt', skiprows=1)

LMC_orbit3 = np.loadtxt('LMCLMC459.txt', skiprows=1)
MW_orbit3 = np.loadtxt('MWLMC459.txt', skiprows=1)
D_orbit3 = np.loadtxt('DiskLMC459.txt', skiprows=1)

# %%
figure(figsize=(18, 6))
subplot(1, 3, 1)
plot(MW_orbit1[:,0], MW_orbit1[:,1], c='b', lw=3)
plt.axhline(MW_orbit1[:,3][0], c='b', ls='--', lw=3)
plot(D_orbit1[:,0], D_orbit1[:,1], c='g', lw=3)
plt.axhline(D_orbit1[:,3][0], c='g', ls='--', lw=3)
xscale('log')

subplot(1, 3, 2)
plot(MW_orbit2[:,0], MW_orbit2[:,2], c='b', lw=3)
#plt.axhline(MW_orbit2[:,3][0], c='b', ls='--', lw=3)
plot(D_orbit2[:,0], D_orbit2[:,2], c='g', lw=3)
#plt.axhline(D_orbit2[:,3][0], c='g', ls='--', lw=3)
xscale('log')


#subplot(1, 3, 3)
#plot(MW_orbit3[:,0], MW_orbit3[:,1], c='b', lw=3)
#plt.axhline(MW_orbit3[:,3][0], c='b', ls='--', lw=3)
#plot(D_orbit3[:,0], D_orbit3[:,1], c='g', lw=3)
#plt.axhline(D_orbit3[:,3][0], c='g', ls='--', lw=3)
#xscale('log')

# %%
figure(figsize=(18, 6))
subplot(1, 3, 1)
plot(LMC_orbit1[:,0], LMC_orbit1[:,1], c='b', lw=3)
plt.axhline(LMC_orbit1[:,3][0], c='b', ls='--', lw=3)
ylim(282, 286)
xscale('log')

subplot(1, 3, 2)
plot(LMC_orbit2[:,0], LMC_orbit2[:,1], c='b', lw=3)
plt.axhline(LMC_orbit2[:,3][0], c='b', ls='--', lw=3)
ylim(282, 286)
xscale('log')


subplot(1, 3, 3)
plot(LMC_orbit3[:,0], LMC_orbit3[:,1], c='b', lw=3)
plt.axhline(LMC_orbit3[:,3][0], c='b', ls='--', lw=3)
ylim(282, 286)
xscale('log')

# %%
figure(figsize=(18, 6))
subplot(1, 3, 1)
plot(LMC_orbit1[:,0], LMC_orbit1[:,2], c='b', lw=3)
plt.axhline(195.23, c='b', ls='--', lw=3)
ylim(192, 199)
xscale('log')

subplot(1, 3, 2)
plot(LMC_orbit2[:,0], LMC_orbit2[:,2], c='b', lw=3)
plt.axhline(195.23, c='b', ls='--', lw=3)
ylim(192, 199)
xscale('log')


subplot(1, 3, 3)
plot(LMC_orbit3[:,0], LMC_orbit3[:,2], c='b', lw=3)
plt.axhline(195.23, c='b', ls='--', lw=3)
ylim(192, 199)
xscale('log')

# %%
## Initial distance:
print 'LMC with 100000 particles'
print LMC_orbit1[:,3][0] - MW_orbit1[:,3][0]
print 'LMC with 300000 particles'
print LMC_orbit2[:,3][0] - MW_orbit2[:,3][0]
print 'LMC with 900000 particles'
print LMC_orbit3[:,3][0] - MW_orbit3[:,3][0]
# Out:
# LMC with 100000 particles
# 278.645941
# LMC with 300000 particles
# 279.620062
# LMC with 900000 particles
# 281.077337

# %%
#The original distance was:
print 'Original Position'
np.sqrt(46.00887**2 + 262.883708**2 + 102.73465**2)
# Out:
# Original Position
# 285.97039770075622

# %%
# The original Velocity
np.sqrt(22.495585**2 + 193.883677**2 + 4.392485**2)
# Out:
# 195.23377135118756
