# %%
# %pylab inline
from pygadgetreader import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
MW_data = readsnap('../data/ICs/MW/5M/MW2-5M_005.hdf5', 'pos', 'disk')
MW_mass = readsnap('../data/ICs/MW/5M/MW2-5M_005.hdf5', 'mass', 'disk')

# %%
figure(figsize=(5,5))
scatter(MW_data[:,0], MW_data[:,1], s=0.1, c=np.log10(MW_mass), edgecolor='none')
xlim(-30, 30)
ylim(-30, 30)
# Out:
# (-30, 30)
