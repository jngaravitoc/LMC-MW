# %%
# %pylab inline
from octopus import profiles
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/dist-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
# Function that reads the data from the Analytic integration
#Galactocentic distances and velocities
def reading_data(snap_name):
    host = loadtxt('../../orbits/data/lmc/'+ snap_name +'_host.txt')
    sat = loadtxt('../../orbits/data/lmc/'+ snap_name +'_sat.txt')
    t = host[:,0] 
    # Defining galactocentric distances and velocities
    x = sat[:,1] - host[:,1] 
    y = sat[:,2] - host[:,2] 
    z = sat[:,3] - host[:,3] 

    vx = sat[:,4] - host[:,4] 
    vy = sat[:,5] - host[:,5] 
    vz = sat[:,6] - host[:,6]        

    Rgal = np.sqrt(x**2.0 + y**2.0 + z**2.0)
    Vgal = np.sqrt(vx**2.0 + vy**2.0 + vz**2.0)
    
    return t, x, y, z, vx, vy, vz, Rgal, Vgal

# %%
t1, xgal1, ygal1, zgal1, vxgal1, vygal1, vzgal1, Rgal1, Vgal1 = reading_data('facundo_mw1_lmc1')
t2, xgal2, ygal2, zgal2, vxgal2, vygal2, vzgal2, Rgal2, Vgal2 = reading_data('facundo_mw1_lmc2')
t3, xgal3, ygal3, zgal3, vxgal3, vygal3, vzgal3, Rgal3, Vgal3 = reading_data('facundo_mw1_lmc3')
t4, xgal4, ygal4, zgal4, vxgal4, vygal4, vzgal4, Rgal4, Vgal4 = reading_data('facundo_mw1_lmc4')
t5, xgal5, ygal5, zgal5, vxgal5, vygal5, vzgal5, Rgal5, Vgal5 = reading_data('facundo_mw1_lmc5')
t6, xgal6, ygal6, zgal6, vxgal6, vygal6, vzgal6, Rgal6, Vgal6 = reading_data('facundo_mw1_lmc6')

t1_2, xgal1_2, ygal1_2, zgal1_2, vxgal1_2, vygal1_2, vzgal1_2, Rgal1_2, Vgal1_2 = reading_data('facundo_mw2_lmc1')
t2_2, xgal2_2, ygal2_2, zgal2_2, vxgal2_2, vygal2_2, vzgal2_2, Rgal2_2, Vgal2_2 = reading_data('facundo_mw2_lmc2')
t3_2, xgal3_2, ygal3_2, zgal3_2, vxgal3_2, vygal3_2, vzgal3_2, Rgal3_2, Vgal3_2 = reading_data('facundo_mw2_lmc3')
t4_2, xgal4_2, ygal4_2, zgal4_2, vxgal4_2, vygal4_2, vzgal4_2, Rgal4_2, Vgal4_2 = reading_data('facundo_mw2_lmc4')
t5_2, xgal5_2, ygal5_2, zgal5_2, vxgal5_2, vygal5_2, vzgal5_2, Rgal5_2, Vgal5_2 = reading_data('facundo_mw2_lmc5')
t6_2, xgal6_2, ygal6_2, zgal6_2, vxgal6_2, vygal6_2, vzgal6_2, Rgal6_2, Vgal6_2 = reading_data('facundo_mw2_lmc6')



t1_ac, xgal1_ac, ygal1_ac, zgal1_ac, vxgal1_ac, vygal1_ac, vzgal1_ac, Rgal1_ac, Vgal1_ac = reading_data('facundo_mw1_lmc1_ac')
t2_ac, xgal2_ac, ygal2_ac, zgal2_ac, vxgal2_ac, vygal2_ac, vzgal2_ac, Rgal2_ac, Vgal2_ac = reading_data('facundo_mw1_lmc2_ac')
t3_ac, xgal3_ac, ygal3_ac, zgal3_ac, vxgal3_ac, vygal3_ac, vzgal3_ac, Rgal3_ac, Vgal3_ac = reading_data('facundo_mw1_lmc3_ac')
t4_ac, xgal4_ac, ygal4_ac, zgal4_ac, vxgal4_ac, vygal4_ac, vzgal4_ac, Rgal4_ac, Vgal4_ac = reading_data('facundo_mw1_lmc4_ac')
t5_ac, xgal5_ac, ygal5_ac, zgal5_ac, vxgal5_ac, vygal5_ac, vzgal5_ac, Rgal5_ac, Vgal5_ac = reading_data('facundo_mw1_lmc5_ac')
t6_ac, xgal6_ac, ygal6_ac, zgal6_ac, vxgal6_ac, vygal6_ac, vzgal6_ac, Rgal6_ac, Vgal6_ac = reading_data('facundo_mw1_lmc6_ac')

t1_2_ac, xgal1_2_ac, ygal1_2_ac, zgal1_2_ac, vxgal1_2_ac, vygal1_2_ac, vzgal1_2_ac, Rgal1_2_ac, Vgal1_2_ac = reading_data('facundo_mw2_lmc1_ac')
t2_2_ac, xgal2_2_ac, ygal2_2_ac, zgal2_2_ac, vxgal2_2_ac, vygal2_2_ac, vzgal2_2_ac, Rgal2_2_ac, Vgal2_2_ac = reading_data('facundo_mw2_lmc2_ac')
t3_2_ac, xgal3_2_ac, ygal3_2_ac, zgal3_2_ac, vxgal3_2_ac, vygal3_2_ac, vzgal3_2_ac, Rgal3_2_ac, Vgal3_2_ac = reading_data('facundo_mw2_lmc3_ac')
t4_2_ac, xgal4_2_ac, ygal4_2_ac, zgal4_2_ac, vxgal4_2_ac, vygal4_2_ac, vzgal4_2_ac, Rgal4_2_ac, Vgal4_2_ac = reading_data('facundo_mw2_lmc4_ac')
t5_2_ac, xgal5_2_ac, ygal5_2_ac, zgal5_2_ac, vxgal5_2_ac, vygal5_2_ac, vzgal5_2_ac, Rgal5_2_ac, Vgal5_2_ac = reading_data('facundo_mw2_lmc5_ac')
t6_2_ac, xgal6_2_ac, ygal6_2_ac, zgal6_2_ac, vxgal6_2_ac, vygal6_2_ac, vzgal6_2_ac, Rgal6_2_ac, Vgal6_2_ac = reading_data('facundo_mw2_lmc6_ac')

# %%
t1_3_ac, xgal1_3_ac, ygal1_3_ac, zgal1_3_ac, vxgal1_3_ac, vygal1_3_ac, vzgal1_3_ac, Rgal1_3_ac, Vgal1_3_ac = reading_data('ekta_mw1_lmc1_ac')
t2_3_ac, xgal2_3_ac, ygal2_3_ac, zgal2_3_ac, vxgal2_3_ac, vygal2_3_ac, vzgal2_3_ac, Rgal2_3_ac, Vgal2_3_ac = reading_data('ekta_mw1_lmc3_ac1')
t3_3_ac, xgal3_3_ac, ygal3_3_ac, zgal3_3_ac, vxgal3_3_ac, vygal3_3_ac, vzgal3_3_ac, Rgal3_3_ac, Vgal3_3_ac = reading_data('ekta_mw1_lmc6_ac')
t4_3_ac, xgal4_3_ac, ygal4_3_ac, zgal4_3_ac, vxgal4_3_ac, vygal4_3_ac, vzgal4_3_ac, Rgal4_3_ac, Vgal4_3_ac = reading_data('ekta_mw2_lmc1_ac')
t5_3_ac, xgal5_3_ac, ygal5_3_ac, zgal5_3_ac, vxgal5_3_ac, vygal5_3_ac, vzgal5_3_ac, Rgal5_3_ac, Vgal5_3_ac = reading_data('ekta_mw2_lmc3_ac')
t6_3_ac, xgal6_3_ac, ygal6_3_ac, zgal6_3_ac, vxgal6_3_ac, vygal6_3_ac, vzgal6_3_ac, Rgal6_3_ac, Vgal6_3_ac = reading_data('ekta_mw2_lmc6_ac')

# %%
t1_3_ac_h, xgal1_3_ac, ygal1_3_ac, zgal1_3_ac, vxgal1_3_ac, vygal1_3_ac, vzgal1_3_ac, Rgal1_3_ac_h, Vgal1_3_ac = reading_data('ekta_mw1_lmc1_ac_h')
t2_3_ac_h, xgal2_3_ac, ygal2_3_ac, zgal2_3_ac, vxgal2_3_ac, vygal2_3_ac, vzgal2_3_ac, Rgal2_3_ac_h, Vgal2_3_ac = reading_data('ekta_mw1_lmc3_ac1_h')
t3_3_ac_h, xgal3_3_ac, ygal3_3_ac, zgal3_3_ac, vxgal3_3_ac, vygal3_3_ac, vzgal3_3_ac, Rgal3_3_ac_h, Vgal3_3_ac = reading_data('ekta_mw1_lmc6_ac_h')
t4_3_ac_h, xgal4_3_ac, ygal4_3_ac, zgal4_3_ac, vxgal4_3_ac, vygal4_3_ac, vzgal4_3_ac, Rgal4_3_ac_h, Vgal4_3_ac = reading_data('ekta_mw2_lmc1_ac_h')
t5_3_ac_h, xgal5_3_ac, ygal5_3_ac, zgal5_3_ac, vxgal5_3_ac, vygal5_3_ac, vzgal5_3_ac, Rgal5_3_ac_h, Vgal5_3_ac = reading_data('ekta_mw2_lmc3_ac_h')
t6_3_ac_h, xgal6_3_ac, ygal6_3_ac, zgal6_3_ac, vxgal6_3_ac, vygal6_3_ac, vzgal6_3_ac, Rgal6_3_ac_h, Vgal6_3_ac = reading_data('ekta_mw2_lmc6_ac_h')

# %%
plot(t1, Vgal1)
plot(t1, Vgal6)
plot(t1_ac, Vgal1_ac)
plot(t6_ac, Vgal6_ac)

# %%
figure(figsize=(12, 5))

subplot(1, 2, 1)
plot(t1, Rgal1, label=r'$3 \times 10^{10}$')
plot(t2, Rgal2, label=r'$5 \times 10^{10}$', c='r')
plot(t3, Rgal3, label=r'$8 \times 10^{10}$', c='g')
plot(t4, Rgal4, label=r'$10 \times 10^{10}$', c='k')
plot(t5, Rgal5, label=r'$18 \times 10^{10}$', c='purple')
plot(t6, Rgal6, label=r'$25 \times 10^{10}$', c='y')

ylim(0, 1000)

xlabel('$t[Gyrs]$', fontsize=25)
ylabel('$r[Kpc]$', fontsize=25)
axhline(261, ls='--', c='k', alpha=0.7)
legend(loc='best', fontsize=12, ncol=1)

#legend(loc='best', fontsize=15)
subplot(1, 2, 2)
plot(t1_2, Rgal1_2, label=r'$3 \times 10^{10}$', c='b')
plot(t2_2, Rgal2_2, label=r'$5 \times 10^{10}$', c='r')
plot(t3_2, Rgal3_2, label=r'$8 \times 10^{10}$', c='g')
plot(t4_2, Rgal4_2, label=r'$10 \times 10^{10}$', c='k')
plot(t5_2, Rgal5_2, label=r'$18 \times 10^{10}$', c='purple')
plot(t6_2, Rgal6_2, label=r'$25 \times 10^{10}$', c='y')


xlabel('$t[Gyrs]$', fontsize=25)
ylabel('$r[Kpc]$', fontsize=25)

axhline(299, ls='--', c='k', alpha=0.7)
#ylim(0, 800)

#savefig('df_test.png', bbox_inches='tight')

# %%
figure(figsize=(12, 5))

subplot(1, 2, 1)
plot(t1_ac, Rgal1_ac, label=r'$3 \times 10^{10}$')
plot(t2_ac, Rgal2_ac, label=r'$5 \times 10^{10}$')
plot(t3_ac, Rgal3_ac, label=r'$8 \times 10^{10}$')
plot(t4_ac, Rgal4_ac, label=r'$10 \times 10^{10}$')
plot(t5_ac, Rgal5_ac, label=r'$18 \times 10^{10}$')
plot(t6_ac, Rgal6_ac, label=r'$25 \times 10^{10}$')


xlabel('$t[Gyrs]$', fontsize=25)
ylabel('$r[Kpc]$', fontsize=25)
axhline(261, ls='--', c='k', alpha=0.7)
legend(loc='best', fontsize=12, ncol=1)

#legend(loc='best', fontsize=15)
subplot(1, 2, 2)
plot(t1_2_ac, Rgal1_2_ac, label=r'$3 \times 10^{10}$')
plot(t2_2_ac, Rgal2_2_ac, label=r'$5 \times 10^{10}$')
plot(t3_2_ac, Rgal3_2_ac, label=r'$8 \times 10^{10}$')
plot(t4_2_ac, Rgal4_2_ac, label=r'$10 \times 10^{10}$')
plot(t5_2_ac, Rgal5_2_ac, label=r'$18 \times 10^{10}$')
plot(t6_2_ac, Rgal6_2_ac, label=r'$25 \times 10^{10}$')


xlabel('$t[Gyrs]$', fontsize=25)
ylabel('$r[Kpc]$', fontsize=25)

axhline(299, ls='--', c='k', alpha=0.7)
#ylim(0, 800)

# %%
figure(figsize(14,5))
subplot(1, 2, 1)
title('$\mathrm{Plummer}$', fontsize=25)
plot(t1_3_ac, Rgal1_3_ac, label=r'$3 \times 10^{10} $', ls='-', lw=1.5)
plot(t2_3_ac, Rgal2_3_ac, label=r'$10 \times 10^{10}$', ls='-', lw=1.5)
plot(t3_3_ac, Rgal3_3_ac, label=r'$25 \times 10^{10}$', ls='-', lw=1.5)
plot(t4_3_ac, Rgal4_3_ac, label=r'$3 \times 10^{10}$', ls='--', lw=1.5)
plot(t5_3_ac, Rgal5_3_ac, label=r'$10 \times 10^{10}$', ls='--', lw=1.5)
plot(t6_3_ac, Rgal6_3_ac, label=r'$25 \times 10^{10}$', ls='--', lw=1.5)
axhline(261, ls='--', c='k', alpha=0.6)
axhline(299, ls='-', c='k', alpha=0.6)
legend(loc='best', ncol=2)
xlim(-6, 0)

subplot(1, 2, 2)
title('$\mathrm{Hernquist}$', fontsize=25)
plot(t1_3_ac_h, Rgal1_3_ac_h, label=r'$3 \times 10^{10} $', ls='-', lw=1.5)
plot(t2_3_ac_h, Rgal2_3_ac_h, label=r'$10 \times 10^{10}$', ls='-', lw=1.5)
plot(t3_3_ac_h, Rgal3_3_ac_h, label=r'$25 \times 10^{10}$', ls='-', lw=1.5)
plot(t4_3_ac_h, Rgal4_3_ac_h, label=r'$3 \times 10^{10}$', ls='--', lw=1.5)
plot(t5_3_ac_h, Rgal5_3_ac_h, label=r'$10 \times 10^{10}$', ls='--', lw=1.5)
plot(t6_3_ac_h, Rgal6_3_ac_h, label=r'$25 \times 10^{10}$', ls='--', lw=1.5)
axhline(261, ls='--', c='k', alpha=0.6)
axhline(299, ls='-', c='k', alpha=0.6)
legend(loc='best', ncol=2)
xlim(-6, 0)

savefig('ektas_orbits.png', bbox_inches='tight')

# %%
tgal1, xgal1, ygal1, zgal1, vxgal1, vygal1, vzgal1, Rgal1, Vgal1 = reading_data('lmc1_Herndf_vdm_cl1')
tgal2, xgal2, ygal2, zgal2, vxgal2, vygal2, vzgal2, Rgal2, Vgal2 = reading_data('lmc3_Herndf_vdm_cl1')
tgal3, xgal3, ygal3, zgal3, vxgal3, vygal3, vzgal3, Rgal3, Vgal3 = reading_data('lmc6_Herndf_vdm_cl1')

tgal4, xgal4, ygal4, zgal4, vxgal4, vygal4, vzgal4, Rgal4, Vgal4 = reading_data('lmc1_Herndf_vdm_cl2-5')
tgal5, xgal5, ygal5, zgal5, vxgal5, vygal5, vzgal5, Rgal5, Vgal5 = reading_data('lmc3_Herndf_vdm_cl2-5')
tgal6, xgal6, ygal6, zgal6, vxgal6, vygal6, vzgal6, Rgal6, Vgal6 = reading_data('lmc6_Herndf_vdm_cl2-5')

tgal4_2, xgal4_2, ygal4_2, zgal4_2, vxgal4_2, vygal4_2, vzgal4_2, Rgal4_2, Vgal4_2 = reading_data('facundo_mw2_lmc1')
tgal5_2, xgal5_2, ygal5_2, zgal5_2, vxgal5_2, vygal5_2, vzgal5_2, Rgal5_2, Vgal5_2 = reading_data('facundo_mw2_lmc2')
tgal6_2, xgal6_2, ygal6_2, zgal6_2, vxgal6_2, vygal6_2, vzgal6_2, Rgal6_2, Vgal6_2 = reading_data('facundo_mw2_lmc3')
tgal4_2, xgal4_2, ygal4_2, zgal4_2, vxgal4_2, vygal4_2, vzgal4_2, Rgal4_2, Vgal4_2 = reading_data('facundo_mw2_lmc1')
tgal5_2, xgal5_2, ygal5_2, zgal5_2, vxgal5_2, vygal5_2, vzgal5_2, Rgal5_2, Vgal5_2 = reading_data('facundo_mw2_lmc2')
tgal6_2, xgal6_2, ygal6_2, zgal6_2, vxgal6_2, vygal6_2, vzgal6_2, Rgal6_2, Vgal6_2 = reading_data('facundo_mw2_lmc3')

#tgal6_2, xgal6_2, ygal6_2, zgal6_2, vxgal6_2, vygal6_2, vzgal6_2, Rgal6_2, Vgal6_2 = reading_data('lmc6_Herndf_vdm_cl2-7')


tgal7, xgal7, ygal7, zgal7, vxgal7, vygal7, vzgal7, Rgal7, Vgal7 = reading_data('lmc1_Herndf_vdm_cl3')
tgal8, xgal8, ygal8, zgal8, vxgal8, vygal8, vzgal8, Rgal8, Vgal8 = reading_data('lmc3_Herndf_vdm_cl3')
tgal9, xgal9, ygal9, zgal9, vxgal9, vygal9, vzgal9, Rgal9, Vgal9 = reading_data('lmc6_Herndf_vdm_cl3')

#tgal1, xgal1, ygal1, zgal1, vxgal1, vygal1, vzgal1, Rgal1, Vgal1 = reading_data('lmc6_Herndf_vdm_cl2')
#tgal1, xgal1, ygal1, zgal1, vxgal1, vygal1, vzgal1, Rgal1, Vgal1 = reading_data('lmc6_Herndf_vdm_cl2')
#tgal1, xgal1, ygal1, zgal1, vxgal1, vygal1, vzgal1, Rgal1, Vgal1 = reading_data('lmc6_Herndf_vdm_cl2')

# %%
figure(figsize=(6, 5))
"""
subplot(1, 3, 1)
plot(tgal1, Rgal1, label=r'$3 \times 10^{10}$')
plot(tgal2, Rgal2, label=r'$10 \times 10^{10}$')#
plot(tgal3, Rgal3, label=r'$25 \times 10^{10}$')#
xlabel('$t[Gyrs]$', fontsize=25)
ylabel('$r[Kpc]$', fontsize=25)
axhline(300, ls='--', c='k', alpha=0.7)
"""
#legend(loc='best', fontsize=15)
#subplot(1, 3, 2)
#plot(tgal4, Rgal4)
#plot(tgal5, Rgal5)
#plot(tgal6, Rgal6)

plot(tgal4_2, Rgal4_2, ls='--', label=r'$3 \times 10^{10}, ac=0$')
plot(tgal5_2, Rgal5_2, ls='--', label=r'$3 \times 10^{10}, ac=1$')
#plot(tgal6_2, Rgal6_2, ls='--', label=r'$25 \times 10^{10}$')

legend(loc='best', fontsize=15)
xlabel('$t[Gyrs]$', fontsize=25)
axhline(300, ls='--', c='k', alpha=0.7)
#ylim(0, 800)

"""
subplot(1, 3, 3)
plot(tgal7, Rgal7)
plot(tgal8, Rgal8)
plot(tgal9, Rgal9)
xlabel('$t[Gyrs]$', fontsize=25)
axhline(300, ls='--', c='k', alpha=0.7) 
"""
savefig('df_test.png', bbox_inches='tight')

# %% [markdown]
# ## from octopus import profiles

# %%
r_grid=logspace(-3, 3, 1000)
Mass_lmc1 = profiles.dens_hernquist(4.5, r_grid, 3E10)
Mass_lmc3 = profiles.dens_hernquist(15, r_grid, 1E11)
Mass_lmc6 = profiles.dens_hernquist(29, r_grid, 2.5E11)

# %%
loglog(r_grid, Mass_lmc1)
loglog(r_grid, Mass_lmc3)
loglog(r_grid, Mass_lmc6)

# %%
r = np.linspace(0, 400, 200)

lmc1_rho = profiles.dens_plummer(5.9, r, 3E10)
lmc3_rho = profiles.dens_plummer(13.1, r, 10E10)
lmc6_rho = profiles.dens_plummer(19, r, 25E10)

lmc1_rho_h = profiles.dens_hernquist(2.9, r, 3E10)
lmc3_rho_h = profiles.dens_hernquist(12.5, r, 10E10)
lmc6_rho_h = profiles.dens_hernquist(25, r, 25E10)

lmc1_m = profiles.mass_plummer(5.9, r, 3E10)
lmc3_m = profiles.mass_plummer(13.1, r, 10E10)
lmc6_m = profiles.mass_plummer(19, r, 25E10)

lmc1_m_h = profiles.mass_hernquist(2.9, r, 3E10)
lmc3_m_h = profiles.mass_hernquist(12.5, r, 10E10)
lmc6_m_h = profiles.mass_hernquist(25, r, 25E10)

# %%
figure(figsize=(15, 6))
subplot(1, 2, 1)
loglog(r, lmc1_rho)
loglog(r, lmc3_rho)
loglog(r, lmc6_rho)

subplot(1, 2, 2)
loglog(r, lmc1_rho_h)
loglog(r, lmc3_rho_h)
loglog(r, lmc6_rho_h)

# %%
loglog(r, lmc1_m)
loglog(r, lmc3_m)
loglog(r, lmc6_m)
axhline(1.7E10)
axvline(8.7)

# %%
loglog(r, lmc1_m_h)
loglog(r, lmc3_m_h)
loglog(r, lmc6_m_h)
axhline(1.7E10)
axvline(8.7)

#xlim(0, 15)
#ylim(10E9, 2E10)

# %%
#n.NFW(Mhalo, 2e-6, 24.).potential() - n.NFW(Mhalo, 1e-6, 24.).potential()/1e-6

# %%
(profiles.pot_NFW(12, 2e-6, 0, 0, 1.5E12) - profiles.pot_NFW(24, 1e-6, 0, 0, 1.5E12))/1e-6
# Out:
# 7.477549986732501e-23

# %%
profiles.pot_NFW?
