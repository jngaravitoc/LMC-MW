# %%
# %pylab inline
from pygadgetreader import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
positions1 = readsnap("MW1LMC3_000", 'pos', 'dm')
positions1_d = readsnap("MW1LMC3_000", 'pos', 'disk')
positions1_b = readsnap("MW1LMC3_000", 'pos', 'bulge')
positions2 = readsnap("MW1LMC3_009", 'pos', 'dm')
# Out:
# Returning DM    Positions
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DM    Positions

# %%
print len(positions1), len(positions1_d)
# Out:
# 60000 10000

# %%
scatter(positions1[:,0], positions1[:,1], s=0.1)
scatter(positions1_d[:,0], positions1_d[:,1], s=10, c='r')
xlim(-300, 300)
ylim(-300, 300)
# Out:
# (-300, 300)

# %%
scatter(positions2[:,0], positions2[:,2], s=0.1)
xlim(-300, 300)
ylim(-300, 300)
# Out:
# (-300, 300)

# %%
combine = readsnap('../ICs/MWLMC/MWLMC1', 'pos', 'dm')
# Out:
# Could not determine file type by extension!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
combine_bulge = readsnap('../ICs/MWLMC/MWLMC1', 'pos', 'bulge')
# Out:
# Could not determine file type by extension!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
scatter(combine[:,0], combine[:,1], s=1, alpha=0.5)
scatter(combine_bulge[:,0], combine_bulge[:,1], s=1, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0fb1bdfe8b99> in <module>()
# ----> 1 scatter(combine[:,0], combine[:,1], s=1, alpha=0.5)
#       2 scatter(combine_bulge[:,0], combine_bulge[:,1], s=1, alpha=0.5)
#
# NameError: name 'combine' is not defined

# %%
scatter(combine_bulge[:,0], combine_bulge[:,1], s=1, alpha=0.5)
